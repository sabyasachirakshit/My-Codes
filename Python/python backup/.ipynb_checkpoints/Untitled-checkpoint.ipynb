# %%
import  pandas as pd
df = pd.read_excel("rail_data2.xlsx")
df
# Out:
#                   Train1   S_Time1                Train2   S_Time2  \
# 0                 Howrah  20:55:00                Howrah  21:50:00
# 1     Kharagpur Junction  22:40:00    Kharagpur Junction  23:25:00
# 2               Balasore  00:24:00    Tatanagar Junction  01:20:00
# 3                Bhadrak  01:35:00         Chakradharpur  02:20:00
# 4   Jaipur Keonjhar Road  02:14:00     Rourkela Junction  03:50:00
# 5       Cuttack Junction  03:20:00   Jharsuguda Junction  05:45:00
# 6            Bhubaneswar  04:05:00          Brajrajnagar  05:55:00
# 7   Khurda Road Junction  04:35:00               Raigarh  06:45:00
# 8                   Puri  05:50:00       Champa Junction  07:47:00
# 9                    NaN       NaN     Bilaspur Junction  08:55:00
# 10                   NaN       NaN             Bhatapara  09:48:00
# 11                   NaN       NaN       Raipur Junction  10:45:00
# 12                   NaN       NaN         Durg Junction  11:35:00
# ...
